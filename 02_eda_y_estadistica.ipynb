# %%
import pandas as pd
import numpy as np

# Cargar el dataset que limpiamos y guardamos en el paso anterior
df = pd.read_csv('../data/processed/ecommerce_procesado.csv')

# Visualizar las primeras 5 filas y comprobar dimensiones
print(f"Dataset cargado con éxito: {df.shape[0]} filas y {df.shape[1]} columnas.\n")
df.head()
